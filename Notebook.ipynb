# %% [raw]
# ---
# title: "WVS Wave 7 Data Pre-processing"
# format: html
# ---

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pingouin as pg
from scipy.stats import zscore


file_path = "Original_Data_Wave_7.csv"   
df = pd.read_csv(file_path, low_memory=False)  

print(df.info())
print(df.head())
print(f"Dataset Shape: {df.shape}") 

print(df.columns)
print(df.head())

df.isnull().sum().sort_values(ascending=False)

latin_american_countries = [   #countries from latin america included in wave 7
    
 "ARG", "BOL", "BRA", "CHL", "COL", "ECU", "GTM", "MEX", "NIC", "PER", "PRI", "URY", "VEN"
 ]

df = df[df['B_COUNTRY_ALPHA'].isin(latin_american_countries)]

print(df)


selected_columns = [          #questions carefully selected after studying the survey completely and literature review
    'A_STUDY', 'A_YEAR', 'B_COUNTRY_ALPHA', 'S025',   # General questions
    'Q57P', 'Q58P', 'Q59P',  'Q60P',   'Q61P',   'Q62P',   'Q63P',  # Interpersonal trust questions
    'Q66P', 'Q67P', 'Q69P',  'Q71P',   'Q72P',   'Q75P',   'Q78P',  # Institutional trust questions
    'Q201P', 'Q202P', 'Q203P',  'Q204P',   'Q205P',   'Q206P',   'Q207P',  # Social media usage questions
    'Q208P', 'Q255P', 'Q256P','Q257P' ,'Q258P','Q259P','Q263', #Independent questions   *maybe to be added to the study* 
    'Q240', #Polarization questions 
    'Q260', 'Q262', #Demographic questions
         
]

df_filtered = df[selected_columns]

print(df_filtered)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 97220 entries, 0 to 97219
# Columns: 611 entries, version to v2xps_party
# dtypes: float64(195), int64(404), object(12)
# memory usage: 453.2+ MB
# None
#               version                        doi  A_WAVE  A_YEAR  A_STUDY  \
# 0  6-0-0 (2024-04-30)  doi.org/10.14281/18241.24       7    2019        2
# 1  6-0-0 (2024-04-30)  doi.org/10.14281/18241.24       7    2019        2
# 2  6-0-0 (2024-04-30)  doi.org/10.14281/18241.24       7    2019        2
# 3  6-0-0 (2024-04-30)  doi.org/10.14281/18241.24       7    2019        2
# 4  6-0-0 (2024-04-30)  doi.org/10.14281/18241.24       7    2019        2
#
#    B_COUNTRY B_COUNTRY_ALPHA  C_COW_NUM C_COW_ALPHA  D_INTERVIEW  ...  \
# 0        196             CYP        352         CYP    196070011  ...
# 1        196             CYP        352         CYP    196070036  ...
# 2        196             CYP        352         CYP    196070039  ...
# 3        196             CYP        352         CYP    196070040  ...
# 4        196             CYP        352         CYP    196070053  ...
#
#    WVS_Polmistrust_PartyVoter  WVS_LR_MedianVoter  WVS_LibCon_MedianVoter  \
# 0                         NaN                 NaN                     NaN
# 1                         NaN                 NaN                     NaN
# 2                         NaN                 NaN                     NaN
# 3                         NaN                 NaN                     NaN
# 4                         NaN                 NaN                     NaN
#
#    v2psbars  v2psorgs  v2psprbrch  v2psprlnks  v2psplats  v2xnp_client  \
# 0       NaN       NaN         NaN         NaN        NaN           NaN
# 1       NaN       NaN         NaN         NaN        NaN           NaN
# 2       NaN       NaN         NaN         NaN        NaN           NaN
# 3       NaN       NaN         NaN         NaN        NaN           NaN
# 4       NaN       NaN         NaN         NaN        NaN           NaN
#
#    v2xps_party
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
#
# [5 rows x 611 columns]
# Dataset Shape: (97220, 611)
# Index(['version', 'doi', 'A_WAVE', 'A_YEAR', 'A_STUDY', 'B_COUNTRY',
#        'B_COUNTRY_ALPHA', 'C_COW_NUM', 'C_COW_ALPHA', 'D_INTERVIEW',
#        ...
#        'WVS_Polmistrust_PartyVoter', 'WVS_LR_MedianVoter',
#        'WVS_LibCon_MedianVoter', 'v2psbars', 'v2psorgs', 'v2psprbrch',
#        'v2psprlnks', 'v2psplats', 'v2xnp_client', 'v2xps_party'],
#       dtype='object', length=611)
#               version                        doi  A_WAVE  A_YEAR  A_STUDY  \
# 0  6-0-0 (2024-04-30)  doi.org/10.14281/18241.24       7    2019        2
# 1  6-0-0 (2024-04-30)  doi.org/10.14281/18241.24       7    2019        2
# 2  6-0-0 (2024-04-30)  doi.org/10.14281/18241.24       7    2019        2
# 3  6-0-0 (2024-04-30)  doi.org/10.14281/18241.24       7    2019        2
# 4  6-0-0 (2024-04-30)  doi.org/10.14281/18241.24       7    2019        2
#
#    B_COUNTRY B_COUNTRY_ALPHA  C_COW_NUM C_COW_ALPHA  D_INTERVIEW  ...  \
# 0        196             CYP        352         CYP    196070011  ...
# 1        196             CYP        352         CYP    196070036  ...
# 2        196             CYP        352         CYP    196070039  ...
# 3        196             CYP        352         CYP    196070040  ...
# 4        196             CYP        352         CYP    196070053  ...
#
#    WVS_Polmistrust_PartyVoter  WVS_LR_MedianVoter  WVS_LibCon_MedianVoter  \
# 0                         NaN                 NaN                     NaN
# 1                         NaN                 NaN                     NaN
# 2                         NaN                 NaN                     NaN
# 3                         NaN                 NaN                     NaN
# 4                         NaN                 NaN                     NaN
#
#    v2psbars  v2psorgs  v2psprbrch  v2psprlnks  v2psplats  v2xnp_client  \
# 0       NaN       NaN         NaN         NaN        NaN           NaN
# 1       NaN       NaN         NaN         NaN        NaN           NaN
# 2       NaN       NaN         NaN         NaN        NaN           NaN
# 3       NaN       NaN         NaN         NaN        NaN           NaN
# 4       NaN       NaN         NaN         NaN        NaN           NaN
#
#    v2xps_party
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
#
# [5 rows x 611 columns]
#                   version                        doi  A_WAVE  A_YEAR  A_STUDY  \
# 22     6-0-0 (2024-04-30)  doi.org/10.14281/18241.24       7    2018        2
# 23     6-0-0 (2024-04-30)  doi.org/10.14281/18241.24       7    2018        2
# 24     6-0-0 (2024-04-30)  doi.org/10.14281/18241.24       7    2018        2
# 25     6-0-0 (2024-04-30)  doi.org/10.14281/18241.24       7    2018        2
# 26     6-0-0 (2024-04-30)  doi.org/10.14281/18241.24       7    2018        2
# ...                   ...                        ...     ...     ...      ...
# 96876  6-0-0 (2024-04-30)  doi.org/10.14281/18241.24       7    2021        2
# 96877  6-0-0 (2024-04-30)  doi.org/10.14281/18241.24       7    2021        2
# 96878  6-0-0 (2024-04-30)  doi.org/10.14281/18241.24       7    2021        2
# 96879  6-0-0 (2024-04-30)  doi.org/10.14281/18241.24       7    2021        2
# 96880  6-0-0 (2024-04-30)  doi.org/10.14281/18241.24       7    2021        2
#
#        B_COUNTRY B_COUNTRY_ALPHA  C_COW_NUM C_COW_ALPHA  D_INTERVIEW  ...  \
# 22           218             ECU        130         ECU    218070001  ...
# 23           218             ECU        130         ECU    218070003  ...
# 24           218             ECU        130         ECU    218070005  ...
# 25           218             ECU        130         ECU    218070017  ...
# 26           218             ECU        130         ECU    218070021  ...
# ...          ...             ...        ...         ...          ...  ...
# 96876        862             VEN        101         VEN    862071011  ...
# 96877        862             VEN        101         VEN    862071070  ...
# 96878        862             VEN        101         VEN    862071077  ...
# 96879        862             VEN        101         VEN    862071101  ...
# 96880        862             VEN        101         VEN    862071111  ...
#
#        WVS_Polmistrust_PartyVoter  WVS_LR_MedianVoter  WVS_LibCon_MedianVoter  \
# 22                            NaN                 NaN                     NaN
# 23                            NaN                 NaN                     NaN
# 24                            NaN                 NaN                     NaN
# 25                            NaN                 NaN                     NaN
# 26                            NaN                 NaN                     NaN
# ...                           ...                 ...                     ...
# 96876                         NaN                 NaN                     NaN
# 96877                         NaN                 NaN                     NaN
# 96878                         NaN                 NaN                     NaN
# 96879                         NaN                 NaN                     NaN
# 96880                         NaN                 NaN                     NaN
#
#        v2psbars  v2psorgs  v2psprbrch  v2psprlnks  v2psplats  v2xnp_client  \
# 22          NaN       NaN         NaN         NaN        NaN           NaN
# 23          NaN       NaN         NaN         NaN        NaN           NaN
# 24          NaN       NaN         NaN         NaN        NaN           NaN
# 25          NaN       NaN         NaN         NaN        NaN           NaN
# 26          NaN       NaN         NaN         NaN        NaN           NaN
# ...         ...       ...         ...         ...        ...           ...
# 96876       NaN       NaN         NaN         NaN        NaN           NaN
# 96877       NaN       NaN         NaN         NaN        NaN           NaN
# 96878       NaN       NaN         NaN         NaN        NaN           NaN
# 96879       NaN       NaN         NaN         NaN        NaN           NaN
# 96880       NaN       NaN         NaN         NaN        NaN           NaN
#
#        v2xps_party
# 22             NaN
# 23             NaN
# 24             NaN
# 25             NaN
# 26             NaN
# ...            ...
# 96876          NaN
# 96877          NaN
# 96878          NaN
# 96879          NaN
# 96880          NaN
#
# [17439 rows x 611 columns]
#        A_STUDY  A_YEAR B_COUNTRY_ALPHA     S025  Q57P  Q58P  Q59P  Q60P  Q61P  \
# 22           2    2018             ECU  2182018     1     4     3     3     2
# 23           2    2018             ECU  2182018     1     4     3     3     1
# 24           2    2018             ECU  2182018     1     4     1     3     2
# 25           2    2018             ECU  2182018     1     4     1     1     2
# 26           2    2018             ECU  2182018     1     3     3     3     3
# ...        ...     ...             ...      ...   ...   ...   ...   ...   ...
# 96876        2    2021             VEN  8622021     2     4     3     4     3
# 96877        2    2021             VEN  8622021     1     3     3     3     2
# 96878        2    2021             VEN  8622021     1     3     3     3     1
# 96879        2    2021             VEN  8622021     1     3     3     3     2
# 96880        2    2021             VEN  8622021     2     4     2     3     2
#
#        Q62P  ...  Q208P  Q255P  Q256P  Q257P  Q258P  Q259P  Q263  Q240  Q260  \
# 22        2  ...      4      2      2      2      2      1     1     5     1
# 23        1  ...      5      4      4      4      3      2     1     5     1
# 24        3  ...      5      4      4      4      4      4     1     5     2
# 25        2  ...      4      3      3      3      3      3     1     5     1
# 26        3  ...      4      4      4      4      4      2     1     5     1
# ...     ...  ...    ...    ...    ...    ...    ...    ...   ...   ...   ...
# 96876     3  ...      4      4      4      4      4      4     1     9     1
# 96877     2  ...      5      3      3      4      4      4     1    10     2
# 96878     1  ...      5      4      4      3      3      3     1     5     2
# 96879     2  ...      5      3      3      4      4      4     1     7     2
# 96880     2  ...      5      4      4      4      2      3     1    10     2
#
#        Q262
# 22       27
# 23       55
# 24       23
# 25       37
# 26       42
# ...     ...
# 96876    69
# 96877    23
# 96878    18
# 96879    52
# 96880    21
#
# [17439 rows x 35 columns]

# %%
rename_columns = {
    'A_STUDY':'a_study',
    'A_YEAR':'a_year',
    'B_COUNTRY_ALPHA' : 'country',
    'S025': 's025',
    'Q57P':'Q57_trust_people',
    'Q58P': 'Q58_trust_family',
    'Q59P': 'Q59_trust_neighborhood',
    'Q60P': 'Q60_trust_friends',     
    'Q61P': 'Q61_trust_new_people',
    'Q62P': 'Q62_trust_people_another_religion',
    'Q63P': 'Q63_trust_foreigners',
    'Q66P': 'Q66_confidence_press',
    'Q67P': 'Q67_confidence_television',
    'Q69P': 'Q69_confidence_police',
    'Q71P': 'Q71_confidence_government',
    'Q72P': 'Q72_confidence_politicalparties',
    'Q75P': 'Q75_confidence_universities',
    'Q76P': 'Q76_confidence_elections',
    'Q77P': 'Q77_confidence_majorcompanies',
    'Q78P': 'Q78_confidence_banks',
    'Q201P':'Q201_consume_dailynewspaper',
    'Q202P':'Q202_consume_TVnews',
    'Q203P':'Q203_consume_radionews',
    'Q204P':'Q204_consume_mobilephone',
    'Q205P':'Q205_consume_email',
    'Q206P': 'Q206_consume_internet',
    'Q207P': 'Q207_consume_socialmedia',
    'Q208P': 'Q208_talk_with_friends_colleagues',
    'Q217P': 'Q217_search_information_politics',
    'Q240': 'Q240_placement_left_right',
    'Q255P': 'Q255_closeness_city',
    'Q256P': 'Q256_closeness_region',
    'Q257P': 'Q257_closeness_country',
    'Q258P': 'Q258_closeness_Latam',
    'Q259P': 'Q259_closeness_World',
    'Q260': 'Q260_gender',
    'Q262': 'Q262_age',
    'Q263': 'Q263_native_Inmigrant',
}

df_filtered.rename(columns=rename_columns, inplace=True)

print(df_filtered.columns)
# Out:
# Index(['a_study', 'a_year', 'country', 's025', 'Q57_trust_people',
#        'Q58_trust_family', 'Q59_trust_neighborhood', 'Q60_trust_friends',
#        'Q61_trust_new_people', 'Q62_trust_people_another_religion',
#        'Q63_trust_foreigners', 'Q66_confidence_press',
#        'Q67_confidence_television', 'Q69_confidence_police',
#        'Q71_confidence_government', 'Q72_confidence_politicalparties',
#        'Q75_confidence_universities', 'Q78_confidence_banks',
#        'Q201_consume_dailynewspaper', 'Q202_consume_TVnews',
#        'Q203_consume_radionews', 'Q204_consume_mobilephone',
#        'Q205_consume_email', 'Q206_consume_internet',
#        'Q207_consume_socialmedia', 'Q208_talk_with_friends_colleagues',
#        'Q255_closeness_city', 'Q256_closeness_region',
#        'Q257_closeness_country', 'Q258_closeness_Latam',
#        'Q259_closeness_World', 'Q263_native_Inmigrant',
#        'Q240_placement_left_right', 'Q260_gender', 'Q262_age'],
#       dtype='object')
# C:\Users\carme\AppData\Local\Temp\ipykernel_23896\2788891895.py:42: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered.rename(columns=rename_columns, inplace=True)

# %%
missing_values = [-1, -2, -3, -5]   #Q240 is the one with the highest missing codes
df_filtered.replace(missing_values, np.nan, inplace=True)

df_filtered.isnull().sum()
# Out:
# C:\Users\carme\AppData\Local\Temp\ipykernel_23896\3564121889.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered.replace(missing_values, np.nan, inplace=True)
# a_study                                 0
# a_year                                  0
# country                                 0
# s025                                    0
# Q57_trust_people                      175
# Q58_trust_family                       39
# Q59_trust_neighborhood                112
# Q60_trust_friends                      93
# Q61_trust_new_people                  128
# Q62_trust_people_another_religion     669
# Q63_trust_foreigners                  664
# Q66_confidence_press                  228
# Q67_confidence_television             124
# Q69_confidence_police                  82
# Q71_confidence_government             175
# Q72_confidence_politicalparties       184
# Q75_confidence_universities           387
# Q78_confidence_banks                  262
# Q201_consume_dailynewspaper           148
# Q202_consume_TVnews                   117
# Q203_consume_radionews                149
# Q204_consume_mobilephone              169
# Q205_consume_email                    271
# Q206_consume_internet                 202
# Q207_consume_socialmedia              439
# Q208_talk_with_friends_colleagues     133
# Q255_closeness_city                   187
# Q256_closeness_region                 219
# Q257_closeness_country                252
# Q258_closeness_Latam                  681
# Q259_closeness_World                  603
# Q263_native_Inmigrant                  26
# Q240_placement_left_right            2333
# Q260_gender                             2
# Q262_age                                5
# dtype: int64

# %%
numerical_stats = df_filtered.describe()

print(numerical_stats)
# Out:
#        a_study        a_year          s025  Q57_trust_people  \
# count  17439.0  17439.000000  1.743900e+04      17264.000000
# mean       2.0   2018.536613  3.628074e+06          1.104611
# std        0.0      1.406047  2.769645e+06          0.306060
# min        2.0   2017.000000  3.220170e+05          1.000000
# 25%        2.0   2018.000000  7.620180e+05          1.000000
# 50%        2.0   2018.000000  3.202020e+06          1.000000
# 75%        2.0   2020.000000  6.042018e+06          1.000000
# max        2.0   2022.000000  8.622021e+06          2.000000
#
#        Q58_trust_family  Q59_trust_neighborhood  Q60_trust_friends  \
# count      17400.000000            17327.000000       17346.000000
# mean           3.557529                2.453281           2.596622
# std            0.731199                0.922106           0.896891
# min            1.000000                1.000000           1.000000
# 25%            3.000000                2.000000           2.000000
# 50%            4.000000                2.000000           3.000000
# 75%            4.000000                3.000000           3.000000
# max            4.000000                4.000000           4.000000
#
#        Q61_trust_new_people  Q62_trust_people_another_religion  \
# count          17311.000000                       16770.000000
# mean               1.703541                           2.187179
# std                0.785063                           0.905699
# min                1.000000                           1.000000
# 25%                1.000000                           1.000000
# 50%                2.000000                           2.000000
# 75%                2.000000                           3.000000
# max                4.000000                           4.000000
#
#        Q63_trust_foreigners  ...  Q208_talk_with_friends_colleagues  \
# count          16775.000000  ...                       17306.000000
# mean               1.981580  ...                           3.547671
# std                0.905559  ...                           1.537082
# min                1.000000  ...                           1.000000
# 25%                1.000000  ...                           2.000000
# 50%                2.000000  ...                           4.000000
# 75%                3.000000  ...                           5.000000
# max                4.000000  ...                           5.000000
#
#        Q255_closeness_city  Q256_closeness_region  Q257_closeness_country  \
# count         17252.000000           17220.000000            17187.000000
# mean              3.337178               3.223868                3.239716
# std               0.779261               0.816875                0.837500
# min               1.000000               1.000000                1.000000
# 25%               3.000000               3.000000                3.000000
# 50%               4.000000               3.000000                3.000000
# 75%               4.000000               4.000000                4.000000
# max               4.000000               4.000000                4.000000
#
#        Q258_closeness_Latam  Q259_closeness_World  Q263_native_Inmigrant  \
# count          16758.000000          16836.000000           17413.000000
# mean               2.635219              2.539024               1.013783
# std                0.989625              1.034980               0.116592
# min                1.000000              1.000000               1.000000
# 25%                2.000000              2.000000               1.000000
# 50%                3.000000              3.000000               1.000000
# 75%                3.000000              3.000000               1.000000
# max                4.000000              4.000000               2.000000
#
#        Q240_placement_left_right   Q260_gender      Q262_age
# count               15106.000000  17437.000000  17434.000000
# mean                    5.681716      1.530424     41.108810
# std                     2.710379      0.499088     16.810876
# min                     1.000000      1.000000     16.000000
# 25%                     5.000000      1.000000     27.000000
# 50%                     5.000000      2.000000     39.000000
# 75%                     8.000000      2.000000     54.000000
# max                    10.000000      2.000000     94.000000
#
# [8 rows x 34 columns]

# %%
sns.countplot(x='country', data=df_filtered)
plt.title("Count of Observations by Country")
plt.xticks(rotation=45)
plt.show()

sns.countplot(x='Q260_gender', data=df_filtered)
plt.title("Count of Observations by Gender")
plt.show()

# %%
countries_names = {
    'ECU': 'Ecuador',
    'ARG': 'Argentina',
    'BOL': 'Bolivia',
    'BRA': 'Brazil',
    'CHL': 'Chile',
    'COL': 'Colombia',
    'MEX': 'Mexico',
    'PER': 'Peru',
    'PRI': 'Paraguay',
    'URY': 'Uruguay',
    'NIC': 'Nicaragua',
    'VEN': 'Venezuela',
    'GTM': 'Guatemala'
    
}

df_filtered['country_name'] = df_filtered['country'].map(countries_names)

print(df_filtered[['country', 'country_name']].head())

df_filtered.reset_index(drop=True, inplace=True)

df_filtered
# Out:
#    country country_name
# 22     ECU      Ecuador
# 23     ECU      Ecuador
# 24     ECU      Ecuador
# 25     ECU      Ecuador
# 26     ECU      Ecuador
# C:\Users\carme\AppData\Local\Temp\ipykernel_23896\329068772.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['country_name'] = df_filtered['country'].map(countries_names)
#        a_study  a_year country     s025  Q57_trust_people  Q58_trust_family  \
# 0            2    2018     ECU  2182018               1.0               4.0
# 1            2    2018     ECU  2182018               1.0               4.0
# 2            2    2018     ECU  2182018               1.0               4.0
# 3            2    2018     ECU  2182018               1.0               4.0
# 4            2    2018     ECU  2182018               1.0               3.0
# ...        ...     ...     ...      ...               ...               ...
# 17434        2    2021     VEN  8622021               2.0               4.0
# 17435        2    2021     VEN  8622021               1.0               3.0
# 17436        2    2021     VEN  8622021               1.0               3.0
# 17437        2    2021     VEN  8622021               1.0               3.0
# 17438        2    2021     VEN  8622021               2.0               4.0
#
#        Q59_trust_neighborhood  Q60_trust_friends  Q61_trust_new_people  \
# 0                         3.0                3.0                   2.0
# 1                         3.0                3.0                   1.0
# 2                         1.0                3.0                   2.0
# 3                         1.0                1.0                   2.0
# 4                         3.0                3.0                   3.0
# ...                       ...                ...                   ...
# 17434                     3.0                4.0                   3.0
# 17435                     3.0                3.0                   2.0
# 17436                     3.0                3.0                   1.0
# 17437                     3.0                3.0                   2.0
# 17438                     2.0                3.0                   2.0
#
#        Q62_trust_people_another_religion  ...  Q255_closeness_city  \
# 0                                    2.0  ...                  2.0
# 1                                    1.0  ...                  4.0
# 2                                    3.0  ...                  4.0
# 3                                    2.0  ...                  3.0
# 4                                    3.0  ...                  4.0
# ...                                  ...  ...                  ...
# 17434                                3.0  ...                  4.0
# 17435                                2.0  ...                  3.0
# 17436                                1.0  ...                  4.0
# 17437                                2.0  ...                  3.0
# 17438                                2.0  ...                  4.0
#
#        Q256_closeness_region  Q257_closeness_country  Q258_closeness_Latam  \
# 0                        2.0                     2.0                   2.0
# 1                        4.0                     4.0                   3.0
# 2                        4.0                     4.0                   4.0
# 3                        3.0                     3.0                   3.0
# 4                        4.0                     4.0                   4.0
# ...                      ...                     ...                   ...
# 17434                    4.0                     4.0                   4.0
# 17435                    3.0                     4.0                   4.0
# 17436                    4.0                     3.0                   3.0
# 17437                    3.0                     4.0                   4.0
# 17438                    4.0                     4.0                   2.0
#
#        Q259_closeness_World  Q263_native_Inmigrant  Q240_placement_left_right  \
# 0                       1.0                    1.0                        5.0
# 1                       2.0                    1.0                        5.0
# 2                       4.0                    1.0                        5.0
# 3                       3.0                    1.0                        5.0
# 4                       2.0                    1.0                        5.0
# ...                     ...                    ...                        ...
# 17434                   4.0                    1.0                        9.0
# 17435                   4.0                    1.0                       10.0
# 17436                   3.0                    1.0                        5.0
# 17437                   4.0                    1.0                        7.0
# 17438                   3.0                    1.0                       10.0
#
#        Q260_gender  Q262_age  country_name
# 0              1.0      27.0       Ecuador
# 1              1.0      55.0       Ecuador
# 2              2.0      23.0       Ecuador
# 3              1.0      37.0       Ecuador
# 4              1.0      42.0       Ecuador
# ...            ...       ...           ...
# 17434          1.0      69.0     Venezuela
# 17435          2.0      23.0     Venezuela
# 17436          2.0      18.0     Venezuela
# 17437          2.0      52.0     Venezuela
# 17438          2.0      21.0     Venezuela
#
# [17439 rows x 36 columns]

# %%
df_filtered['gender_label'] = df_filtered['Q260_gender'].replace({1: 'Male', 2: 'Female'})


sns.countplot(x='gender_label', data=df_filtered)
plt.title("Count of Observations by Gender")
plt.show()
# Out:
# C:\Users\carme\AppData\Local\Temp\ipykernel_23896\3454783711.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['gender_label'] = df_filtered['Q260_gender'].replace({1: 'Male', 2: 'Female'})

# %%
df_filtered.info()

df_filtered['citizen_type'] = df_filtered['Q263_native_Inmigrant'].map({
    1.0: 'Native',
    2.0: 'Inmigrant',
})

df_filtered
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17439 entries, 0 to 17438
# Data columns (total 37 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   a_study                            17439 non-null  int64
#  1   a_year                             17439 non-null  int64
#  2   country                            17439 non-null  object
#  3   s025                               17439 non-null  int64
#  4   Q57_trust_people                   17264 non-null  float64
#  5   Q58_trust_family                   17400 non-null  float64
#  6   Q59_trust_neighborhood             17327 non-null  float64
#  7   Q60_trust_friends                  17346 non-null  float64
#  8   Q61_trust_new_people               17311 non-null  float64
#  9   Q62_trust_people_another_religion  16770 non-null  float64
#  10  Q63_trust_foreigners               16775 non-null  float64
#  11  Q66_confidence_press               17211 non-null  float64
#  12  Q67_confidence_television          17315 non-null  float64
#  13  Q69_confidence_police              17357 non-null  float64
#  14  Q71_confidence_government          17264 non-null  float64
#  15  Q72_confidence_politicalparties    17255 non-null  float64
#  16  Q75_confidence_universities        17052 non-null  float64
#  17  Q78_confidence_banks               17177 non-null  float64
#  18  Q201_consume_dailynewspaper        17291 non-null  float64
#  19  Q202_consume_TVnews                17322 non-null  float64
#  20  Q203_consume_radionews             17290 non-null  float64
#  21  Q204_consume_mobilephone           17270 non-null  float64
#  22  Q205_consume_email                 17168 non-null  float64
#  23  Q206_consume_internet              17237 non-null  float64
#  24  Q207_consume_socialmedia           17000 non-null  float64
#  25  Q208_talk_with_friends_colleagues  17306 non-null  float64
#  26  Q255_closeness_city                17252 non-null  float64
#  27  Q256_closeness_region              17220 non-null  float64
#  28  Q257_closeness_country             17187 non-null  float64
#  29  Q258_closeness_Latam               16758 non-null  float64
#  30  Q259_closeness_World               16836 non-null  float64
#  31  Q263_native_Inmigrant              17413 non-null  float64
#  32  Q240_placement_left_right          15106 non-null  float64
#  33  Q260_gender                        17437 non-null  float64
#  34  Q262_age                           17434 non-null  float64
#  35  country_name                       17439 non-null  object
#  36  gender_label                       17437 non-null  object
# dtypes: float64(31), int64(3), object(3)
# memory usage: 4.9+ MB
# C:\Users\carme\AppData\Local\Temp\ipykernel_23896\500780831.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['citizen_type'] = df_filtered['Q263_native_Inmigrant'].map({
#        a_study  a_year country     s025  Q57_trust_people  Q58_trust_family  \
# 0            2    2018     ECU  2182018               1.0               4.0
# 1            2    2018     ECU  2182018               1.0               4.0
# 2            2    2018     ECU  2182018               1.0               4.0
# 3            2    2018     ECU  2182018               1.0               4.0
# 4            2    2018     ECU  2182018               1.0               3.0
# ...        ...     ...     ...      ...               ...               ...
# 17434        2    2021     VEN  8622021               2.0               4.0
# 17435        2    2021     VEN  8622021               1.0               3.0
# 17436        2    2021     VEN  8622021               1.0               3.0
# 17437        2    2021     VEN  8622021               1.0               3.0
# 17438        2    2021     VEN  8622021               2.0               4.0
#
#        Q59_trust_neighborhood  Q60_trust_friends  Q61_trust_new_people  \
# 0                         3.0                3.0                   2.0
# 1                         3.0                3.0                   1.0
# 2                         1.0                3.0                   2.0
# 3                         1.0                1.0                   2.0
# 4                         3.0                3.0                   3.0
# ...                       ...                ...                   ...
# 17434                     3.0                4.0                   3.0
# 17435                     3.0                3.0                   2.0
# 17436                     3.0                3.0                   1.0
# 17437                     3.0                3.0                   2.0
# 17438                     2.0                3.0                   2.0
#
#        Q62_trust_people_another_religion  ...  Q257_closeness_country  \
# 0                                    2.0  ...                     2.0
# 1                                    1.0  ...                     4.0
# 2                                    3.0  ...                     4.0
# 3                                    2.0  ...                     3.0
# 4                                    3.0  ...                     4.0
# ...                                  ...  ...                     ...
# 17434                                3.0  ...                     4.0
# 17435                                2.0  ...                     4.0
# 17436                                1.0  ...                     3.0
# 17437                                2.0  ...                     4.0
# 17438                                2.0  ...                     4.0
#
#        Q258_closeness_Latam  Q259_closeness_World  Q263_native_Inmigrant  \
# 0                       2.0                   1.0                    1.0
# 1                       3.0                   2.0                    1.0
# 2                       4.0                   4.0                    1.0
# 3                       3.0                   3.0                    1.0
# 4                       4.0                   2.0                    1.0
# ...                     ...                   ...                    ...
# 17434                   4.0                   4.0                    1.0
# 17435                   4.0                   4.0                    1.0
# 17436                   3.0                   3.0                    1.0
# 17437                   4.0                   4.0                    1.0
# 17438                   2.0                   3.0                    1.0
#
#        Q240_placement_left_right  Q260_gender  Q262_age  country_name  \
# 0                            5.0          1.0      27.0       Ecuador
# 1                            5.0          1.0      55.0       Ecuador
# 2                            5.0          2.0      23.0       Ecuador
# 3                            5.0          1.0      37.0       Ecuador
# 4                            5.0          1.0      42.0       Ecuador
# ...                          ...          ...       ...           ...
# 17434                        9.0          1.0      69.0     Venezuela
# 17435                       10.0          2.0      23.0     Venezuela
# 17436                        5.0          2.0      18.0     Venezuela
# 17437                        7.0          2.0      52.0     Venezuela
# 17438                       10.0          2.0      21.0     Venezuela
#
#        gender_label  citizen_type
# 0              Male        Native
# 1              Male        Native
# 2            Female        Native
# 3              Male        Native
# 4              Male        Native
# ...             ...           ...
# 17434          Male        Native
# 17435        Female        Native
# 17436        Female        Native
# 17437        Female        Native
# 17438        Female        Native
#
# [17439 rows x 38 columns]

# %%
sns.countplot(x='citizen_type', hue='gender_label', data=df_filtered)
plt.title("Native vs Immigrant by Gender")
plt.xlabel("Respondent Condition")
plt.ylabel("Count")
plt.show()

# %%
age_unique = df_filtered['Q262_age'].unique()

print(age_unique)

df_filtered['age_group'] = pd.cut(df_filtered['Q262_age'], bins=[14,18, 29, 44, 59, 74, 100], 
                          labels=["18-", "18-29", "30-44", "45-59", "60-74", "75+"], right=False)

print(df_filtered['age_group'].value_counts())

df_filtered
# Out:
# [27. 55. 23. 37. 42. 53. 59. 63. 32. 46. 21. 73. 34. 49. 58. 30. 48. 41.
#  51. 36. 35. 31. 22. 45. 62. 40. 68. 18. 66. 43. 28. 24. 54. 29. 39. 33.
#  60. 57. 25. 64. 56. 52. 19. 61. 26. 38. 20. 75. 76. 67. 44. 70. 65. 80.
#  50. 71. 17. 69. 47. 74. 78. 86. 87. 72. 77. 79. 84. 81. nan 94. 83. 85.
#  82. 91. 88. 89. 16. 90. 92. 93.]
# age_group
# 30-44    5188
# 18-29    4949
# 45-59    3974
# 60-74    2567
# 75+       629
# 18-       127
# Name: count, dtype: int64
# C:\Users\carme\AppData\Local\Temp\ipykernel_23896\3810614445.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['age_group'] = pd.cut(df_filtered['Q262_age'], bins=[14,18, 29, 44, 59, 74, 100],
#        a_study  a_year country     s025  Q57_trust_people  Q58_trust_family  \
# 0            2    2018     ECU  2182018               1.0               4.0
# 1            2    2018     ECU  2182018               1.0               4.0
# 2            2    2018     ECU  2182018               1.0               4.0
# 3            2    2018     ECU  2182018               1.0               4.0
# 4            2    2018     ECU  2182018               1.0               3.0
# ...        ...     ...     ...      ...               ...               ...
# 17434        2    2021     VEN  8622021               2.0               4.0
# 17435        2    2021     VEN  8622021               1.0               3.0
# 17436        2    2021     VEN  8622021               1.0               3.0
# 17437        2    2021     VEN  8622021               1.0               3.0
# 17438        2    2021     VEN  8622021               2.0               4.0
#
#        Q59_trust_neighborhood  Q60_trust_friends  Q61_trust_new_people  \
# 0                         3.0                3.0                   2.0
# 1                         3.0                3.0                   1.0
# 2                         1.0                3.0                   2.0
# 3                         1.0                1.0                   2.0
# 4                         3.0                3.0                   3.0
# ...                       ...                ...                   ...
# 17434                     3.0                4.0                   3.0
# 17435                     3.0                3.0                   2.0
# 17436                     3.0                3.0                   1.0
# 17437                     3.0                3.0                   2.0
# 17438                     2.0                3.0                   2.0
#
#        Q62_trust_people_another_religion  ...  Q258_closeness_Latam  \
# 0                                    2.0  ...                   2.0
# 1                                    1.0  ...                   3.0
# 2                                    3.0  ...                   4.0
# 3                                    2.0  ...                   3.0
# 4                                    3.0  ...                   4.0
# ...                                  ...  ...                   ...
# 17434                                3.0  ...                   4.0
# 17435                                2.0  ...                   4.0
# 17436                                1.0  ...                   3.0
# 17437                                2.0  ...                   4.0
# 17438                                2.0  ...                   2.0
#
#        Q259_closeness_World  Q263_native_Inmigrant  Q240_placement_left_right  \
# 0                       1.0                    1.0                        5.0
# 1                       2.0                    1.0                        5.0
# 2                       4.0                    1.0                        5.0
# 3                       3.0                    1.0                        5.0
# 4                       2.0                    1.0                        5.0
# ...                     ...                    ...                        ...
# 17434                   4.0                    1.0                        9.0
# 17435                   4.0                    1.0                       10.0
# 17436                   3.0                    1.0                        5.0
# 17437                   4.0                    1.0                        7.0
# 17438                   3.0                    1.0                       10.0
#
#        Q260_gender  Q262_age  country_name  gender_label  citizen_type  \
# 0              1.0      27.0       Ecuador          Male        Native
# 1              1.0      55.0       Ecuador          Male        Native
# 2              2.0      23.0       Ecuador        Female        Native
# 3              1.0      37.0       Ecuador          Male        Native
# 4              1.0      42.0       Ecuador          Male        Native
# ...            ...       ...           ...           ...           ...
# 17434          1.0      69.0     Venezuela          Male        Native
# 17435          2.0      23.0     Venezuela        Female        Native
# 17436          2.0      18.0     Venezuela        Female        Native
# 17437          2.0      52.0     Venezuela        Female        Native
# 17438          2.0      21.0     Venezuela        Female        Native
#
#        age_group
# 0          18-29
# 1          45-59
# 2          18-29
# 3          30-44
# 4          30-44
# ...          ...
# 17434      60-74
# 17435      18-29
# 17436      18-29
# 17437      45-59
# 17438      18-29
#
# [17439 rows x 39 columns]

# %%
unique_values = {col: df_filtered[col].unique() for col in df_filtered.columns}
for col, values in unique_values.items():
    print(f"Column: {col}")
    print(f"Unique values: {values}\n")
# Out:
# Column: a_study
# Unique values: [2]
#
# Column: a_year
# Unique values: [2018 2017 2022 2020 2021]
#
# Column: country
# Unique values: ['ECU' 'ARG' 'BOL' 'BRA' 'CHL' 'COL' 'MEX' 'PER' 'PRI' 'URY' 'NIC' 'VEN'
#  'GTM']
#
# Column: s025
# Unique values: [2182018  322017  682017  762018 1522018 1702018 4842018 6042018 6302018
#  8582022 5582020 8622021 3202020]
#
# Column: Q57_trust_people
# Unique values: [ 1.  2. nan]
#
# Column: Q58_trust_family
# Unique values: [ 4.  3.  1.  2. nan]
#
# Column: Q59_trust_neighborhood
# Unique values: [ 3.  1.  4.  2. nan]
#
# Column: Q60_trust_friends
# Unique values: [ 3.  1.  4.  2. nan]
#
# Column: Q61_trust_new_people
# Unique values: [ 2.  1.  3.  4. nan]
#
# Column: Q62_trust_people_another_religion
# Unique values: [ 2.  1.  3.  4. nan]
#
# Column: Q63_trust_foreigners
# Unique values: [ 2.  1.  3.  4. nan]
#
# Column: Q66_confidence_press
# Unique values: [ 3.  2.  1.  4. nan]
#
# Column: Q67_confidence_television
# Unique values: [ 3.  2.  1.  4. nan]
#
# Column: Q69_confidence_police
# Unique values: [ 3.  2.  1.  4. nan]
#
# Column: Q71_confidence_government
# Unique values: [ 2.  1.  3.  4. nan]
#
# Column: Q72_confidence_politicalparties
# Unique values: [ 2.  1.  3.  4. nan]
#
# Column: Q75_confidence_universities
# Unique values: [ 3.  4. nan  2.  1.]
#
# Column: Q78_confidence_banks
# Unique values: [ 3.  2.  4.  1. nan]
#
# Column: Q201_consume_dailynewspaper
# Unique values: [ 4.  2.  3.  5.  1. nan]
#
# Column: Q202_consume_TVnews
# Unique values: [ 4.  2.  5.  3.  1. nan]
#
# Column: Q203_consume_radionews
# Unique values: [ 4.  2.  5.  1.  3. nan]
#
# Column: Q204_consume_mobilephone
# Unique values: [ 3.  5.  1.  2. nan  4.]
#
# Column: Q205_consume_email
# Unique values: [ 3.  4.  5.  1.  2. nan]
#
# Column: Q206_consume_internet
# Unique values: [ 3.  5.  4.  1. nan  2.]
#
# Column: Q207_consume_socialmedia
# Unique values: [ 3.  5.  4.  1. nan  2.]
#
# Column: Q208_talk_with_friends_colleagues
# Unique values: [ 4.  5.  3.  2.  1. nan]
#
# Column: Q255_closeness_city
# Unique values: [ 2.  4.  3. nan  1.]
#
# Column: Q256_closeness_region
# Unique values: [ 2.  4.  3.  1. nan]
#
# Column: Q257_closeness_country
# Unique values: [ 2.  4.  3. nan  1.]
#
# Column: Q258_closeness_Latam
# Unique values: [ 2.  3.  4. nan  1.]
#
# Column: Q259_closeness_World
# Unique values: [ 1.  2.  4.  3. nan]
#
# Column: Q263_native_Inmigrant
# Unique values: [ 1.  2. nan]
#
# Column: Q240_placement_left_right
# Unique values: [ 5.  7. nan  6.  3. 10.  2.  1.  8.  4.  9.]
#
# Column: Q260_gender
# Unique values: [ 1.  2. nan]
#
# Column: Q262_age
# Unique values: [27. 55. 23. 37. 42. 53. 59. 63. 32. 46. 21. 73. 34. 49. 58. 30. 48. 41.
#  51. 36. 35. 31. 22. 45. 62. 40. 68. 18. 66. 43. 28. 24. 54. 29. 39. 33.
#  60. 57. 25. 64. 56. 52. 19. 61. 26. 38. 20. 75. 76. 67. 44. 70. 65. 80.
#  50. 71. 17. 69. 47. 74. 78. 86. 87. 72. 77. 79. 84. 81. nan 94. 83. 85.
#  82. 91. 88. 89. 16. 90. 92. 93.]
#
# Column: country_name
# Unique values: ['Ecuador' 'Argentina' 'Bolivia' 'Brazil' 'Chile' 'Colombia' 'Mexico'
#  'Peru' 'Paraguay' 'Uruguay' 'Nicaragua' 'Venezuela' 'Guatemala']
#
# Column: gender_label
# Unique values: ['Male' 'Female' nan]
#
# Column: citizen_type
# Unique values: ['Native' 'Inmigrant' nan]
#
# Column: age_group
# Unique values: ['18-29', '45-59', '30-44', '60-74', '75+', '18-', NaN]
# Categories (6, object): ['18-' < '18-29' < '30-44' < '45-59' < '60-74' < '75+']

# %%
#Social Trust Index
df_filtered['Q57_trust_question_rescaled'] = df_filtered['Q57_trust_people'].map({1: 1, 2: 4, np.nan: np.nan})  # Rescale the 1-2 question to match the 1-4 scale

trust_columns = [
    'Q57_trust_question_rescaled', 'Q58_trust_family', 'Q59_trust_neighborhood', 'Q60_trust_friends', 
    'Q61_trust_new_people', 'Q62_trust_people_another_religion', 'Q63_trust_foreigners'
]
df_filtered['social_trust_index'] = df_filtered[trust_columns].mean(axis=1, skipna=True)  # Create the Social Trust Index (mean of trust-related questions)

print(df_filtered[['social_trust_index']].describe())


df_filtered
# Out:
#        social_trust_index
# count        17432.000000
# mean             2.260969
# std              0.560389
# min              1.000000
# 25%              1.857143
# 50%              2.285714
# 75%              2.571429
# max              4.000000
# C:\Users\carme\AppData\Local\Temp\ipykernel_23896\3677156975.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['Q57_trust_question_rescaled'] = df_filtered['Q57_trust_people'].map({1: 1, 2: 4, np.nan: np.nan})  # Rescale the 1-2 question to match the 1-4 scale
# C:\Users\carme\AppData\Local\Temp\ipykernel_23896\3677156975.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['social_trust_index'] = df_filtered[trust_columns].mean(axis=1, skipna=True)  # Create the Social Trust Index (mean of trust-related questions)
#        a_study  a_year country     s025  Q57_trust_people  Q58_trust_family  \
# 0            2    2018     ECU  2182018               1.0               4.0
# 1            2    2018     ECU  2182018               1.0               4.0
# 2            2    2018     ECU  2182018               1.0               4.0
# 3            2    2018     ECU  2182018               1.0               4.0
# 4            2    2018     ECU  2182018               1.0               3.0
# ...        ...     ...     ...      ...               ...               ...
# 17434        2    2021     VEN  8622021               2.0               4.0
# 17435        2    2021     VEN  8622021               1.0               3.0
# 17436        2    2021     VEN  8622021               1.0               3.0
# 17437        2    2021     VEN  8622021               1.0               3.0
# 17438        2    2021     VEN  8622021               2.0               4.0
#
#        Q59_trust_neighborhood  Q60_trust_friends  Q61_trust_new_people  \
# 0                         3.0                3.0                   2.0
# 1                         3.0                3.0                   1.0
# 2                         1.0                3.0                   2.0
# 3                         1.0                1.0                   2.0
# 4                         3.0                3.0                   3.0
# ...                       ...                ...                   ...
# 17434                     3.0                4.0                   3.0
# 17435                     3.0                3.0                   2.0
# 17436                     3.0                3.0                   1.0
# 17437                     3.0                3.0                   2.0
# 17438                     2.0                3.0                   2.0
#
#        Q62_trust_people_another_religion  ...  Q263_native_Inmigrant  \
# 0                                    2.0  ...                    1.0
# 1                                    1.0  ...                    1.0
# 2                                    3.0  ...                    1.0
# 3                                    2.0  ...                    1.0
# 4                                    3.0  ...                    1.0
# ...                                  ...  ...                    ...
# 17434                                3.0  ...                    1.0
# 17435                                2.0  ...                    1.0
# 17436                                1.0  ...                    1.0
# 17437                                2.0  ...                    1.0
# 17438                                2.0  ...                    1.0
#
#        Q240_placement_left_right  Q260_gender  Q262_age  country_name  \
# 0                            5.0          1.0      27.0       Ecuador
# 1                            5.0          1.0      55.0       Ecuador
# 2                            5.0          2.0      23.0       Ecuador
# 3                            5.0          1.0      37.0       Ecuador
# 4                            5.0          1.0      42.0       Ecuador
# ...                          ...          ...       ...           ...
# 17434                        9.0          1.0      69.0     Venezuela
# 17435                       10.0          2.0      23.0     Venezuela
# 17436                        5.0          2.0      18.0     Venezuela
# 17437                        7.0          2.0      52.0     Venezuela
# 17438                       10.0          2.0      21.0     Venezuela
#
#        gender_label  citizen_type  age_group  Q57_trust_question_rescaled  \
# 0              Male        Native      18-29                          1.0
# 1              Male        Native      45-59                          1.0
# 2            Female        Native      18-29                          1.0
# 3              Male        Native      30-44                          1.0
# 4              Male        Native      30-44                          1.0
# ...             ...           ...        ...                          ...
# 17434          Male        Native      60-74                          4.0
# 17435        Female        Native      18-29                          1.0
# 17436        Female        Native      18-29                          1.0
# 17437        Female        Native      45-59                          1.0
# 17438        Female        Native      18-29                          4.0
#
#        social_trust_index
# 0                2.428571
# 1                2.000000
# 2                2.428571
# 3                1.714286
# 4                2.714286
# ...                   ...
# 17434            3.285714
# 17435            2.285714
# 17436            1.857143
# 17437            2.285714
# 17438            2.714286
#
# [17439 rows x 41 columns]

# %%
#Social Media Usage Index 

import numpy as np

reverse_scale = {1: 5, 2: 4, 3: 3, 4: 2, 5: 1, np.nan: np.nan}


social_media_columns = [
    'Q204_consume_mobilephone', 'Q205_consume_email', 
    'Q206_consume_internet', 'Q207_consume_socialmedia',
    'Q208_talk_with_friends_colleagues'
]


for col in social_media_columns:
    df_filtered[f'{col}_rescaled'] = df_filtered[col].map(reverse_scale)


rescaled_cols = [f'{col}_rescaled' for col in social_media_columns]
df_filtered['social_media_usage_index'] = df_filtered[rescaled_cols].mean(axis=1, skipna=True)

print(df_filtered['social_media_usage_index'].describe())

df_filtered
# Out:
# count    17372.000000
# mean         2.753458
# std          1.371125
# min          1.000000
# 25%          1.600000
# 50%          2.500000
# 75%          4.200000
# max          5.000000
# Name: social_media_usage_index, dtype: float64
# C:\Users\carme\AppData\Local\Temp\ipykernel_23896\334085100.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered[f'{col}_rescaled'] = df_filtered[col].map(reverse_scale)
# C:\Users\carme\AppData\Local\Temp\ipykernel_23896\334085100.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered[f'{col}_rescaled'] = df_filtered[col].map(reverse_scale)
# C:\Users\carme\AppData\Local\Temp\ipykernel_23896\334085100.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered[f'{col}_rescaled'] = df_filtered[col].map(reverse_scale)
# C:\Users\carme\AppData\Local\Temp\ipykernel_23896\334085100.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered[f'{col}_rescaled'] = df_filtered[col].map(reverse_scale)
# C:\Users\carme\AppData\Local\Temp\ipykernel_23896\334085100.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered[f'{col}_rescaled'] = df_filtered[col].map(reverse_scale)
# C:\Users\carme\AppData\Local\Temp\ipykernel_23896\334085100.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['social_media_usage_index'] = df_filtered[rescaled_cols].mean(axis=1, skipna=True)
#        a_study  a_year country     s025  Q57_trust_people  Q58_trust_family  \
# 0            2    2018     ECU  2182018               1.0               4.0
# 1            2    2018     ECU  2182018               1.0               4.0
# 2            2    2018     ECU  2182018               1.0               4.0
# 3            2    2018     ECU  2182018               1.0               4.0
# 4            2    2018     ECU  2182018               1.0               3.0
# ...        ...     ...     ...      ...               ...               ...
# 17434        2    2021     VEN  8622021               2.0               4.0
# 17435        2    2021     VEN  8622021               1.0               3.0
# 17436        2    2021     VEN  8622021               1.0               3.0
# 17437        2    2021     VEN  8622021               1.0               3.0
# 17438        2    2021     VEN  8622021               2.0               4.0
#
#        Q59_trust_neighborhood  Q60_trust_friends  Q61_trust_new_people  \
# 0                         3.0                3.0                   2.0
# 1                         3.0                3.0                   1.0
# 2                         1.0                3.0                   2.0
# 3                         1.0                1.0                   2.0
# 4                         3.0                3.0                   3.0
# ...                       ...                ...                   ...
# 17434                     3.0                4.0                   3.0
# 17435                     3.0                3.0                   2.0
# 17436                     3.0                3.0                   1.0
# 17437                     3.0                3.0                   2.0
# 17438                     2.0                3.0                   2.0
#
#        Q62_trust_people_another_religion  ...  citizen_type  age_group  \
# 0                                    2.0  ...        Native      18-29
# 1                                    1.0  ...        Native      45-59
# 2                                    3.0  ...        Native      18-29
# 3                                    2.0  ...        Native      30-44
# 4                                    3.0  ...        Native      30-44
# ...                                  ...  ...           ...        ...
# 17434                                3.0  ...        Native      60-74
# 17435                                2.0  ...        Native      18-29
# 17436                                1.0  ...        Native      18-29
# 17437                                2.0  ...        Native      45-59
# 17438                                2.0  ...        Native      18-29
#
#        Q57_trust_question_rescaled  social_trust_index  \
# 0                              1.0            2.428571
# 1                              1.0            2.000000
# 2                              1.0            2.428571
# 3                              1.0            1.714286
# 4                              1.0            2.714286
# ...                            ...                 ...
# 17434                          4.0            3.285714
# 17435                          1.0            2.285714
# 17436                          1.0            1.857143
# 17437                          1.0            2.285714
# 17438                          4.0            2.714286
#
#        Q204_consume_mobilephone_rescaled  Q205_consume_email_rescaled  \
# 0                                    3.0                          3.0
# 1                                    3.0                          2.0
# 2                                    1.0                          2.0
# 3                                    5.0                          3.0
# 4                                    1.0                          1.0
# ...                                  ...                          ...
# 17434                                1.0                          2.0
# 17435                                1.0                          5.0
# 17436                                1.0                          5.0
# 17437                                1.0                          5.0
# 17438                                1.0                          3.0
#
#        Q206_consume_internet_rescaled  Q207_consume_socialmedia_rescaled  \
# 0                                 3.0                                3.0
# 1                                 1.0                                1.0
# 2                                 1.0                                1.0
# 3                                 3.0                                2.0
# 4                                 2.0                                1.0
# ...                               ...                                ...
# 17434                             1.0                                1.0
# 17435                             1.0                                1.0
# 17436                             1.0                                1.0
# 17437                             2.0                                2.0
# 17438                             2.0                                2.0
#
#        Q208_talk_with_friends_colleagues_rescaled  social_media_usage_index
# 0                                             2.0                       2.8
# 1                                             1.0                       1.6
# 2                                             1.0                       1.2
# 3                                             2.0                       3.0
# 4                                             2.0                       1.4
# ...                                           ...                       ...
# 17434                                         2.0                       1.4
# 17435                                         1.0                       1.8
# 17436                                         1.0                       1.8
# 17437                                         1.0                       2.2
# 17438                                         1.0                       1.8
#
# [17439 rows x 47 columns]

# %%
# Set a consistent style
sns.set_style('whitegrid')

# List of indices to plot
indices = ['social_trust_index', 'social_media_usage_index']

# Plot each index independently
for index in indices:
    plt.figure(figsize=(10, 5))

    # Histogram
    plt.subplot(1, 2, 1)
    sns.histplot(df_filtered[index], kde=True, color='royalblue')
    plt.title(f'{index} - Distribution')
    plt.xlabel('Index Value')
    plt.ylabel('Frequency')

    # Box plot
    plt.subplot(1, 2, 2)
    sns.boxplot(y=df_filtered[index], color='yellow')
    plt.title(f'{index} - Box Plot')

    plt.tight_layout()
    plt.show()

# %%
social_trust_data = df_filtered[[
    'Q57_trust_people',
    'Q58_trust_family',
    'Q59_trust_neighborhood',
    'Q60_trust_friends',
    'Q61_trust_new_people',
    'Q62_trust_people_another_religion',
    'Q63_trust_foreigners'
]]

alpha = pg.cronbach_alpha(social_trust_data)

print(f"Cronbach's Alpha for Social Trust Index: {alpha[0]:.3f}")  # internal consistency or reliability = acceptable


social_media_data = social_media_columns = df_filtered[['Q204_consume_mobilephone', 'Q205_consume_email', 
    'Q206_consume_internet', 'Q207_consume_socialmedia',
    'Q208_talk_with_friends_colleagues']
]

alpha2 = pg.cronbach_alpha(social_media_data)

print(f"Cronbach's Alpha for Social Media Index: {alpha2[0]:.3f}")
# Out:
# Cronbach's Alpha for Social Trust Index: 0.769
# Cronbach's Alpha for Social Media Index: 0.863

# %%
df_filtered['polarization_index'] = abs(df_filtered['Q240_placement_left_right'] - 5.5)  #creation of polarization index based on extremity score *Political leaning - 5.5*

df_filtered
# Out:
# C:\Users\carme\AppData\Local\Temp\ipykernel_23896\913546193.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['polarization_index'] = abs(df_filtered['Q240_placement_left_right'] - 5.5)
#        a_study  a_year country     s025  Q57_trust_people  Q58_trust_family  \
# 0            2    2018     ECU  2182018               1.0               4.0
# 1            2    2018     ECU  2182018               1.0               4.0
# 2            2    2018     ECU  2182018               1.0               4.0
# 3            2    2018     ECU  2182018               1.0               4.0
# 4            2    2018     ECU  2182018               1.0               3.0
# ...        ...     ...     ...      ...               ...               ...
# 17434        2    2021     VEN  8622021               2.0               4.0
# 17435        2    2021     VEN  8622021               1.0               3.0
# 17436        2    2021     VEN  8622021               1.0               3.0
# 17437        2    2021     VEN  8622021               1.0               3.0
# 17438        2    2021     VEN  8622021               2.0               4.0
#
#        Q59_trust_neighborhood  Q60_trust_friends  Q61_trust_new_people  \
# 0                         3.0                3.0                   2.0
# 1                         3.0                3.0                   1.0
# 2                         1.0                3.0                   2.0
# 3                         1.0                1.0                   2.0
# 4                         3.0                3.0                   3.0
# ...                       ...                ...                   ...
# 17434                     3.0                4.0                   3.0
# 17435                     3.0                3.0                   2.0
# 17436                     3.0                3.0                   1.0
# 17437                     3.0                3.0                   2.0
# 17438                     2.0                3.0                   2.0
#
#        Q62_trust_people_another_religion  ...  age_group  \
# 0                                    2.0  ...      18-29
# 1                                    1.0  ...      45-59
# 2                                    3.0  ...      18-29
# 3                                    2.0  ...      30-44
# 4                                    3.0  ...      30-44
# ...                                  ...  ...        ...
# 17434                                3.0  ...      60-74
# 17435                                2.0  ...      18-29
# 17436                                1.0  ...      18-29
# 17437                                2.0  ...      45-59
# 17438                                2.0  ...      18-29
#
#        Q57_trust_question_rescaled  social_trust_index  \
# 0                              1.0            2.428571
# 1                              1.0            2.000000
# 2                              1.0            2.428571
# 3                              1.0            1.714286
# 4                              1.0            2.714286
# ...                            ...                 ...
# 17434                          4.0            3.285714
# 17435                          1.0            2.285714
# 17436                          1.0            1.857143
# 17437                          1.0            2.285714
# 17438                          4.0            2.714286
#
#        Q204_consume_mobilephone_rescaled  Q205_consume_email_rescaled  \
# 0                                    3.0                          3.0
# 1                                    3.0                          2.0
# 2                                    1.0                          2.0
# 3                                    5.0                          3.0
# 4                                    1.0                          1.0
# ...                                  ...                          ...
# 17434                                1.0                          2.0
# 17435                                1.0                          5.0
# 17436                                1.0                          5.0
# 17437                                1.0                          5.0
# 17438                                1.0                          3.0
#
#        Q206_consume_internet_rescaled  Q207_consume_socialmedia_rescaled  \
# 0                                 3.0                                3.0
# 1                                 1.0                                1.0
# 2                                 1.0                                1.0
# 3                                 3.0                                2.0
# 4                                 2.0                                1.0
# ...                               ...                                ...
# 17434                             1.0                                1.0
# 17435                             1.0                                1.0
# 17436                             1.0                                1.0
# 17437                             2.0                                2.0
# 17438                             2.0                                2.0
#
#        Q208_talk_with_friends_colleagues_rescaled  social_media_usage_index  \
# 0                                             2.0                       2.8
# 1                                             1.0                       1.6
# 2                                             1.0                       1.2
# 3                                             2.0                       3.0
# 4                                             2.0                       1.4
# ...                                           ...                       ...
# 17434                                         2.0                       1.4
# 17435                                         1.0                       1.8
# 17436                                         1.0                       1.8
# 17437                                         1.0                       2.2
# 17438                                         1.0                       1.8
#
#        polarization_index
# 0                     0.5
# 1                     0.5
# 2                     0.5
# 3                     0.5
# 4                     0.5
# ...                   ...
# 17434                 3.5
# 17435                 4.5
# 17436                 0.5
# 17437                 1.5
# 17438                 4.5
#
# [17439 rows x 48 columns]

# %%
df_filtered = df_filtered.dropna(subset=['polarization_index', 'social_trust_index', 'social_media_usage_index'])

df_filtered['polarization_zscore'] = zscore(df_filtered['polarization_index'])  #z-normalization applied in each indexes. 
df_filtered['social_trust_zscore'] = zscore(df_filtered['social_trust_index'])
df_filtered['digital_media_zscore'] = zscore(df_filtered['social_media_usage_index'])


print(df_filtered[['polarization_zscore', 'social_trust_zscore', 'digital_media_zscore']].head())

df_filtered
# Out:
#    polarization_zscore  social_trust_zscore  digital_media_zscore
# 0            -0.971175             0.282227              0.084295
# 1            -0.971175            -0.482958             -0.804039
# 2            -0.971175             0.282227             -1.100151
# 3            -0.971175            -0.993081              0.232350
# 4            -0.971175             0.792349             -0.952095
#        a_study  a_year country     s025  Q57_trust_people  Q58_trust_family  \
# 0            2    2018     ECU  2182018               1.0               4.0
# 1            2    2018     ECU  2182018               1.0               4.0
# 2            2    2018     ECU  2182018               1.0               4.0
# 3            2    2018     ECU  2182018               1.0               4.0
# 4            2    2018     ECU  2182018               1.0               3.0
# ...        ...     ...     ...      ...               ...               ...
# 17434        2    2021     VEN  8622021               2.0               4.0
# 17435        2    2021     VEN  8622021               1.0               3.0
# 17436        2    2021     VEN  8622021               1.0               3.0
# 17437        2    2021     VEN  8622021               1.0               3.0
# 17438        2    2021     VEN  8622021               2.0               4.0
#
#        Q59_trust_neighborhood  Q60_trust_friends  Q61_trust_new_people  \
# 0                         3.0                3.0                   2.0
# 1                         3.0                3.0                   1.0
# 2                         1.0                3.0                   2.0
# 3                         1.0                1.0                   2.0
# 4                         3.0                3.0                   3.0
# ...                       ...                ...                   ...
# 17434                     3.0                4.0                   3.0
# 17435                     3.0                3.0                   2.0
# 17436                     3.0                3.0                   1.0
# 17437                     3.0                3.0                   2.0
# 17438                     2.0                3.0                   2.0
#
#        Q62_trust_people_another_religion  ...  \
# 0                                    2.0  ...
# 1                                    1.0  ...
# 2                                    3.0  ...
# 3                                    2.0  ...
# 4                                    3.0  ...
# ...                                  ...  ...
# 17434                                3.0  ...
# 17435                                2.0  ...
# 17436                                1.0  ...
# 17437                                2.0  ...
# 17438                                2.0  ...
#
#        Q204_consume_mobilephone_rescaled  Q205_consume_email_rescaled  \
# 0                                    3.0                          3.0
# 1                                    3.0                          2.0
# 2                                    1.0                          2.0
# 3                                    5.0                          3.0
# 4                                    1.0                          1.0
# ...                                  ...                          ...
# 17434                                1.0                          2.0
# 17435                                1.0                          5.0
# 17436                                1.0                          5.0
# 17437                                1.0                          5.0
# 17438                                1.0                          3.0
#
#        Q206_consume_internet_rescaled  Q207_consume_socialmedia_rescaled  \
# 0                                 3.0                                3.0
# 1                                 1.0                                1.0
# 2                                 1.0                                1.0
# 3                                 3.0                                2.0
# 4                                 2.0                                1.0
# ...                               ...                                ...
# 17434                             1.0                                1.0
# 17435                             1.0                                1.0
# 17436                             1.0                                1.0
# 17437                             2.0                                2.0
# 17438                             2.0                                2.0
#
#        Q208_talk_with_friends_colleagues_rescaled  social_media_usage_index  \
# 0                                             2.0                       2.8
# 1                                             1.0                       1.6
# 2                                             1.0                       1.2
# 3                                             2.0                       3.0
# 4                                             2.0                       1.4
# ...                                           ...                       ...
# 17434                                         2.0                       1.4
# 17435                                         1.0                       1.8
# 17436                                         1.0                       1.8
# 17437                                         1.0                       2.2
# 17438                                         1.0                       1.8
#
#        polarization_index  polarization_zscore  social_trust_zscore  \
# 0                     0.5            -0.971175             0.282227
# 1                     0.5            -0.971175            -0.482958
# 2                     0.5            -0.971175             0.282227
# 3                     0.5            -0.971175            -0.993081
# 4                     0.5            -0.971175             0.792349
# ...                   ...                  ...                  ...
# 17434                 3.5             0.813196             1.812595
# 17435                 4.5             1.407986             0.027165
# 17436                 0.5            -0.971175            -0.738019
# 17437                 1.5            -0.376384             0.027165
# 17438                 4.5             1.407986             0.792349
#
#        digital_media_zscore
# 0                  0.084295
# 1                 -0.804039
# 2                 -1.100151
# 3                  0.232350
# 4                 -0.952095
# ...                     ...
# 17434             -0.952095
# 17435             -0.655984
# 17436             -0.655984
# 17437             -0.359872
# 17438             -0.655984
#
# [15060 rows x 51 columns]

# %%
df_filtered[['polarization_zscore', 'social_trust_zscore', 'digital_media_zscore']].describe()
# Out:
#        polarization_zscore  social_trust_zscore  digital_media_zscore
# count         1.506000e+04         1.506000e+04          1.506000e+04
# mean          9.058712e-17         1.132339e-17          9.813605e-17
# std           1.000033e+00         1.000033e+00          1.000033e+00
# min          -9.711746e-01        -2.268388e+00         -1.248206e+00
# 25%          -9.711746e-01        -7.380193e-01         -9.520950e-01
# 50%          -3.763844e-01         2.716506e-02         -2.118166e-01
# 75%           1.407986e+00         5.372880e-01          9.726288e-01
# max           1.407986e+00         3.087903e+00          1.712907e+00

# %%
sns.histplot(df_filtered['polarization_zscore'], kde=True, color='blue', label='Polarization')
sns.histplot(df_filtered['social_trust_zscore'], kde=True, color='green', label='Social Trust')
sns.histplot(df_filtered['digital_media_zscore'], kde=True, color='red', label='Digital Media')
plt.legend()
plt.show()

# %%
correlation_matrix = df_filtered[['polarization_zscore', 'social_trust_zscore', 'digital_media_zscore']].corr()
print(correlation_matrix)

sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', vmin=-1, vmax=1)
plt.show()
# Out:
#                       polarization_zscore  social_trust_zscore  \
# polarization_zscore              1.000000             0.019023
# social_trust_zscore              0.019023             1.000000
# digital_media_zscore             0.030829            -0.134945
#
#                       digital_media_zscore
# polarization_zscore               0.030829
# social_trust_zscore              -0.134945
# digital_media_zscore              1.000000
